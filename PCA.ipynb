# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as snb

# %%
# Importing the dataset 
df = pd.read_csv('wine.csv')

# %%
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
# Missing and null values in dataset
df.sum().isnull()
# Out:
# Type               False
# Alcohol            False
# Malic              False
# Ash                False
# Alcalinity         False
# Magnesium          False
# Phenols            False
# Flavanoids         False
# Nonflavanoids      False
# Proanthocyanins    False
# Color              False
# Hue                False
# Dilution           False
# Proline            False
# dtype: bool

# %%
# Histogram of the dataset
df.hist()
# Out:
# array([[<Axes: title={'center': 'Type'}>,
#         <Axes: title={'center': 'Alcohol'}>,
#         <Axes: title={'center': 'Malic'}>,
#         <Axes: title={'center': 'Ash'}>],
#        [<Axes: title={'center': 'Alcalinity'}>,
#         <Axes: title={'center': 'Magnesium'}>,
#         <Axes: title={'center': 'Phenols'}>,
#         <Axes: title={'center': 'Flavanoids'}>],
#        [<Axes: title={'center': 'Nonflavanoids'}>,
#         <Axes: title={'center': 'Proanthocyanins'}>,
#         <Axes: title={'center': 'Color'}>,
#         <Axes: title={'center': 'Hue'}>],
#        [<Axes: title={'center': 'Dilution'}>,
#         <Axes: title={'center': 'Proline'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Boxplots to identify potential outliers 
df.plot.box()
# Out:
# <Axes: >

# %%
# Density plot
df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# Correlation heatmap
snb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# From the above heatmap we can infer that type, magnesium and phenol columns have high correlation

# %%
# Let us perform feature scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()

# %%
df2 = pd.DataFrame(std.fit_transform(df))

# %%
df2
# Out:
#            0         1         2         3         4         5         6   \
# 0   -1.213944  1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997
# 1   -1.213944  0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648
# 2   -1.213944  0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997
# 3   -1.213944  1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446
# 4   -1.213944  0.295700  0.227694  1.840403  0.451946  1.281985  0.808997
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  1.373864  0.876275  2.974543  0.305159  0.301803 -0.332922 -0.985614
# 174  1.373864  0.493343  1.412609  0.414820  1.052516  0.158572 -0.793334
# 175  1.373864  0.332758  1.744744 -0.389355  0.151661  1.422412 -1.129824
# 176  1.373864  0.209232  0.227694  0.012732  0.151661  1.422412 -1.033684
# 177  1.373864  1.395086  1.583165  1.365208  1.502943 -0.262708 -0.392751
#
#            7         8         9         10        11        12        13
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %%
df2.rename(columns={0:'Type', 1:'Alcohol', 2:'Malic', 3:'Ash', 4:'Alcalinity', 5:'Magnesium', 6:'Phenols',
       7:'Flavanoids', 8:'Nonflavanoids', 9:'Proanthocyanins', 10:'Color', 11:'Hue',
       12:'Dilution', 13:'Proline'},inplace=True)

# %%
df2
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.213944  1.518613 -0.562250  0.232053   -1.169593   1.913905  0.808997
# 1   -1.213944  0.246290 -0.499413 -0.827996   -2.490847   0.018145  0.568648
# 2   -1.213944  0.196879  0.021231  1.109334   -0.268738   0.088358  0.808997
# 3   -1.213944  1.691550 -0.346811  0.487926   -0.809251   0.930918  2.491446
# 4   -1.213944  0.295700  0.227694  1.840403    0.451946   1.281985  0.808997
# ..        ...       ...       ...       ...         ...        ...       ...
# 173  1.373864  0.876275  2.974543  0.305159    0.301803  -0.332922 -0.985614
# 174  1.373864  0.493343  1.412609  0.414820    1.052516   0.158572 -0.793334
# 175  1.373864  0.332758  1.744744 -0.389355    0.151661   1.422412 -1.129824
# 176  1.373864  0.209232  0.227694  0.012732    0.151661   1.422412 -1.033684
# 177  1.373864  1.395086  1.583165  1.365208    1.502943  -0.262708 -0.392751
#
# ...

# %%
# implementing PCA to reduce dimensionality
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
pca.fit(df2)
# Out:
# PCA(n_components=3)

# %%
data_pca = pca.transform(df2)

# %%
data_pca = pd.DataFrame(data_pca,columns=['P1','P2','P3'])

# %%
# Principal components of the original dataset
data_pca
# Out:
#            P1        P2        P3
# 0   -3.522934 -1.453098 -0.164795
# 1   -2.528858  0.330019 -2.026707
# 2   -2.785029 -1.036936  0.983238
# 3   -3.922588 -2.768210 -0.174968
# 4   -1.407511 -0.867773  2.025829
# ..        ...       ...       ...
# 173  3.627996 -2.206617 -0.343668
# 174  2.942729 -1.752263  0.207480
# 175  3.027272 -2.756040 -0.940803
# 176  2.755222 -2.293784 -0.550474
# 177  3.496336 -2.760608  1.013151
#
# [178 rows x 3 columns]

# %%
from sklearn.cluster import KMeans

# %%
mod1 = KMeans(n_clusters=4)

# %%
# We will perform clustering on the original dataset

# %%
lab = mod1.fit_predict(df2)
# Out:
# /Users/rmanoj/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
unique = np.unique(lab)

# %%
x = df2.values

# %%
centroids = mod1.cluster_centers_

# %%
plt.figure(figsize=(8, 8)) 
for i in unique: 
    plt.scatter(x[lab==i, 0], x[lab==i, 1], label=i) 
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=169, linewidths=3, color='k', zorder=10) 
plt.legend() 
plt.show()

# %%
# silhoutte score for clustering done on normal dataframe

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(x,lab)
# Out:
# 0.2657134841990162

# %%
# Now let us perform clustering on Reduce PCA components

# %%
mod2 = KMeans(n_clusters=4)

# %%
label = mod2.fit_predict(data_pca)
# Out:
# /Users/rmanoj/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
un = np.unique(label)

# %%
cent = mod2.cluster_centers_

# %%
y = data_pca.values

# %%
plt.figure(figsize=(8, 8)) 
for i in un: 
    plt.scatter(y[label==i, 0], x[label==i, 1], label=i) 
plt.scatter(cent[:, 0], cent[:, 1], marker='x', s=169, linewidths=3, color='k', zorder=10) 
plt.legend() 
plt.show()

# %%
# silhouette score for clustering performed on PCA data

# %%
silhouette_score(y,label)
# Out:
# 0.4373730550531828

# %% [raw]
# # As it can be observed the silhouette score is much higher when we used PCA thus whenever we are dealing with data with many features it is best advised to use PCA for better results
